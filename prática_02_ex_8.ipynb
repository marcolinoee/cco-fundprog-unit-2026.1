# %%
num1 = float(input('Insira um número para saber sua tabuada: '))

for mult in range(1,11):
    resultado = num1 * mult
    print(f"{num1} x {mult} = {resultado}")
# Out:
# Insira um número para saber sua tabuada: 3.4
# 3.4 x 1 = 3.4
# 3.4 x 2 = 6.8
# 3.4 x 3 = 10.2
# 3.4 x 4 = 13.6
# 3.4 x 5 = 17.0
# 3.4 x 6 = 20.4
# 3.4 x 7 = 23.8
# 3.4 x 8 = 27.2
# 3.4 x 9 = 30.599999999999998
# 3.4 x 10 = 34.0
