# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoarthurts08/cco-fundprog-unit-2026.1/blob/entrega-aula-02/pratica_02_ex_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
maior = 0

for i in range(5):
  nota = float(input(f'\nInsira a {i + 1}ª nota: '))

  if nota > maior:
   maior = nota

print(f'\nA maior nota no grupo foi: {maior}')
# Out:
# Insira a 1ª nota: 0
#
# Insira a 2ª nota: 4
#
# Insira a 3ª nota: 8
#
# Insira a 4ª nota: 6
#
# Insira a 5ª nota: 10
#
# A maior nota no grupo foi: 10.0
