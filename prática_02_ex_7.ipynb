# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoarthurts08/cco-fundprog-unit-2026.1/blob/entrega-aula-02/pr%C3%A1tica_02_ex_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
soma = 0

for num in range(1,9):
  if num % 2 == 0:
    soma += num
    print(soma)
# Out:
# 2
# 6
# 12
# 20
